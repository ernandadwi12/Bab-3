# %%
https://github.com/shankarpandala/lazypredict 
! pip install lazypredit
# Out:
#   Cell In[1], line 1
#     https://github.com/shankarpandala/lazypredict
#           ^
# SyntaxError: invalid syntax

# %%
import lazypredict
from lazypredict.Supervised import LazyClassifier
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
X, y = load_iris(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=.25,random_state =1)
clf = LazyClassifier()
models,predictions = clf.fit(X_train, X_test, y_train, y_test)
print(models)
# Out:
#                                Accuracy  Balanced Accuracy   ROC AUC  \
# Model
# LabelPropagation               1.000000           1.000000  1.000000
# QuadraticDiscriminantAnalysis  1.000000           1.000000  1.000000
# LinearDiscriminantAnalysis     1.000000           1.000000  1.000000
# LabelSpreading                 1.000000           1.000000  1.000000
# ExtraTreeClassifier            0.973684           0.979167  0.982759
# BaggingClassifier              0.973684           0.979167  1.000000
# DecisionTreeClassifier         0.973684           0.979167  0.982759
# ExtraTreesClassifier           0.973684           0.979167  1.000000
# AdaBoostClassifier             0.973684           0.979167  0.973932
# SGDClassifier                  0.973684           0.979167       NaN
# SVC                            0.973684           0.979167       NaN
# RandomForestClassifier         0.973684           0.979167  1.000000
# GaussianNB                     0.973684           0.979167  1.000000
# LogisticRegression             0.973684           0.979167  1.000000
# NuSVC                          0.973684           0.979167       NaN
# KNeighborsClassifier           0.973684           0.979167  0.998948
# LinearSVC                      0.894737           0.916667       NaN
# NearestCentroid                0.894737           0.900463  1.000000
# Perceptron                     0.868421           0.895833       NaN
# CalibratedClassifierCV         0.815789           0.854167  0.979335
# RidgeClassifierCV              0.789474           0.833333       NaN
# RidgeClassifier                0.789474           0.833333       NaN
# BernoulliNB                    0.789474           0.817130  0.929281
# PassiveAggressiveClassifier    0.763158           0.812500       NaN
# DummyClassifier                0.236842           0.333333  0.500000
#
#                                F1 Score  Precision    Recall  Time Taken
# Model
# LabelPropagation               1.000000   1.000000  1.000000    0.016043
# QuadraticDiscriminantAnalysis  1.000000   1.000000  1.000000    0.014554
# LinearDiscriminantAnalysis     1.000000   1.000000  1.000000    0.016203
# LabelSpreading                 1.000000   1.000000  1.000000    0.017040
# ExtraTreeClassifier            0.973952   0.976316  0.973684    0.017220
# BaggingClassifier              0.973952   0.976316  0.973684    0.026283
# DecisionTreeClassifier         0.973952   0.976316  0.973684    0.013887
# ExtraTreesClassifier           0.973952   0.976316  0.973684    0.077467
# AdaBoostClassifier             0.973952   0.976316  0.973684    0.084374
# SGDClassifier                  0.973952   0.976316  0.973684    0.013877
# SVC                            0.973952   0.976316  0.973684    0.013578
# RandomForestClassifier         0.973952   0.976316  0.973684    0.098693
# GaussianNB                     0.973952   0.976316  0.973684    0.016029
# LogisticRegression             0.973952   0.976316  0.973684    0.020225
# NuSVC                          0.973952   0.976316  0.973684    0.015027
# KNeighborsClassifier           0.973952   0.976316  0.973684    0.016073
# LinearSVC                      0.896787   0.927126  0.894737    0.012968
# NearestCentroid                0.896491   0.905332  0.894737    0.017540
# Perceptron                     0.866295   0.902689  0.868421    0.015038
# CalibratedClassifierCV         0.815789   0.896382  0.815789    0.045446
# RidgeClassifierCV              0.786775   0.888545  0.789474    0.014744
# RidgeClassifier                0.786775   0.888545  0.789474    0.015042
# BernoulliNB                    0.785692   0.831955  0.789474    0.015216
# PassiveAggressiveClassifier    0.737261   0.832756  0.763158    0.015116
# DummyClassifier                0.090705   0.056094  0.236842    0.013210

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 5))
plt.plot(models.index, models['Accuracy'])

# %%
import lazypredict
from lazypredict.Supervised import LazyRegressor
from sklearn import datasets
from sklearn.utils import shuffle
import numpy as np
from sklearn.datasets import fetch_california_housing
X, y = fetch_california_housing(return_X_y=True, as_frame=True)
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=.1,random_state =1)
reg = LazyRegressor()
models, predictions = reg.fit(X_train, X_test, y_train, y_test)
print(models)
# Out:
#                                Adjusted R-Squared  R-Squared      RMSE  \
# Model
# HistGradientBoostingRegressor            0.830081   0.830740  0.477085
# RandomForestRegressor                    0.811296   0.812027  0.502766
# ExtraTreesRegressor                      0.809712   0.810450  0.504871
# BaggingRegressor                         0.799180   0.799959  0.518654
# MLPRegressor                             0.783910   0.784748  0.538012
# GradientBoostingRegressor                0.781842   0.782688  0.540580
# NuSVR                                    0.745389   0.746376  0.584001
# SVR                                      0.743362   0.744357  0.586321
# KNeighborsRegressor                      0.690845   0.692043  0.643522
# DecisionTreeRegressor                    0.618512   0.619992  0.714850
# ElasticNetCV                             0.599548   0.601101  0.732403
# LassoCV                                  0.599545   0.601098  0.732406
# LarsCV                                   0.599393   0.600946  0.732544
# LassoLarsCV                              0.599393   0.600946  0.732544
# RidgeCV                                  0.599310   0.600864  0.732620
# HuberRegressor                           0.599244   0.600798  0.732681
# BayesianRidge                            0.599239   0.600793  0.732685
# Ridge                                    0.599233   0.600787  0.732691
# Lars                                     0.599224   0.600778  0.732699
# LinearRegression                         0.599224   0.600778  0.732699
# TransformedTargetRegressor               0.599224   0.600778  0.732699
# LassoLarsIC                              0.599224   0.600778  0.732699
# LinearSVR                                0.598053   0.599612  0.733769
# OrthogonalMatchingPursuitCV              0.594085   0.595659  0.737382
# SGDRegressor                             0.540944   0.542724  0.784165
# ExtraTreeRegressor                       0.535528   0.537330  0.788777
# OrthogonalMatchingPursuit                0.473995   0.476035  0.839401
# PoissonRegressor                         0.446211   0.448358  0.861285
# AdaBoostRegressor                        0.442738   0.444899  0.863982
# RANSACRegressor                          0.426536   0.428760  0.876451
# TweedieRegressor                         0.395004   0.397350  0.900225
# GammaRegressor                           0.381123   0.383523  0.910493
# PassiveAggressiveRegressor               0.264452   0.267304  0.992614
# ElasticNet                               0.200488   0.203588  1.034873
# DummyRegressor                          -0.004788  -0.000891  1.160144
# Lasso                                   -0.004788  -0.000891  1.160144
# LassoLars                               -0.004788  -0.000891  1.160144
# QuantileRegressor                       -0.045968  -0.041911  1.183679
#
#                                Time Taken
# Model
# HistGradientBoostingRegressor    0.359566
# RandomForestRegressor            6.678166
# ExtraTreesRegressor              3.389093
# BaggingRegressor                 0.692153
# MLPRegressor                     3.928051
# GradientBoostingRegressor        2.590333
# NuSVR                            8.839724
# SVR                              7.137901
# KNeighborsRegressor              0.110234
# DecisionTreeRegressor            0.121226
# ElasticNetCV                     0.220153
# LassoCV                          0.257398
# LarsCV                           0.183800
# LassoLarsCV                      0.035071
# RidgeCV                          0.032041
# HuberRegressor                   0.098994
# BayesianRidge                    0.020233
# Ridge                            0.017199
# Lars                             0.366169
# LinearRegression                 0.017325
# TransformedTargetRegressor       0.019766
# LassoLarsIC                      0.057306
# LinearSVR                        0.472576
# OrthogonalMatchingPursuitCV      0.027786
# SGDRegressor                     0.024604
# ExtraTreeRegressor               0.043215
# OrthogonalMatchingPursuit        0.015305
# PoissonRegressor                 0.031092
# AdaBoostRegressor                0.695515
# RANSACRegressor                  0.122690
# TweedieRegressor                 0.023380
# GammaRegressor                   0.026532
# PassiveAggressiveRegressor       0.032450
# ElasticNet                       0.017644
# DummyRegressor                   0.010520
# Lasso                            0.049459
# LassoLars                        0.015516
# QuantileRegressor                6.068970

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 5))
plt.plot(models.index, models['R-Squared'],'-s')
